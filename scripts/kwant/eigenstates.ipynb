# %%
import kwant
import numpy as np
import matplotlib.pyplot as plt
from src.ladder_hamiltonian import hamiltonian

sys = hamiltonian().finalized()
bands = kwant.physics.Bands(sys)
kpts = np.linspace(-np.pi, np.pi, 100)

k = 0
eigvals, eigvecs = bands(k, return_eigenvectors=True)

plt.plot(kpts, energies)
