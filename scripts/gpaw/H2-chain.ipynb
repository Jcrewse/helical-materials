# %%
from src.systems import create_system
from gpaw import GPAW, PW, FermiDirac
import numpy as np

# Default parameters for the ground state calculation
params = {
'xc'          : 'PBE',                   # Exchange-correlation func. ID
'h'           : 0.1,                     # Spatial grid size
'kpoints'     : (8,1,1),                 # k-points sampled in periodic sys
'random'      : True,                    # Random guess (of what?)
'occupations' : FermiDirac(0.01),        # Occupation number smearing
'convergence' : {'energy' : 0.0005}      # Convergence criteria
}

# Create H_2 chain
system = create_system('H2-chain', angle = np.pi/3, cell_size = 1)

# Look at the structure
system.view(range = (1,1,1))

print('Calculating ground state...')

# Set up GPAW calculator
calc = GPAW(txt = 'output.log')

calc.default_parameters = params

# Associate the GPAW calculator with the hBN system
system.sys.calc = calc

# Perform some calculations
E       = system.e_ground = system.sys.get_potential_energy()
E_fermi = system.e_fermi  = calc.get_fermi_level()

print('Ground state energy: {:3.4f} eV'.format(E))
print('Fermi energy:        {:3.4f} eV'.format(E_fermi))

# Write to gpw file
calc.write('outfile.gpw', mode = 'all')
# Out:
# Size of unit cell: 3
# Calculating ground state...
# Timing:                              incl.     excl.
# -----------------------------------------------------------
# Hamiltonian:                         0.045     0.000   0.0% |
#  Atomic:                             0.032     0.001   0.0% |
#   XC Correction:                     0.031     0.031   0.1% |
#  Calculate atomic Hamiltonians:      0.001     0.001   0.0% |
#  Communicate:                        0.000     0.000   0.0% |
#  Hartree integrate/restrict:         0.001     0.001   0.0% |
#  Initialize Hamiltonian:             0.000     0.000   0.0% |
#  Poisson:                            0.008     0.000   0.0% |
#   Communicate from 1D:               0.001     0.001   0.0% |
#   Communicate from 2D:               0.001     0.001   0.0% |
#   Communicate to 1D:                 0.001     0.001   0.0% |
#   Communicate to 2D:                 0.001     0.001   0.0% |
#   FFT 1D:                            0.001     0.001   0.0% |
#   FFT 2D:                            0.003     0.003   0.0% |
#  XC 3D grid:                         0.002     0.002   0.0% |
#  vbar:                               0.000     0.000   0.0% |
# LCAO initialization:                 0.037     0.006   0.0% |
#  LCAO eigensolver:                   0.005     0.000   0.0% |
#   Calculate projections:             0.000     0.000   0.0% |
#   DenseAtomicCorrection:             0.000     0.000   0.0% |
#   Distribute overlap matrix:         0.000     0.000   0.0% |
#   Orbital Layouts:                   0.000     0.000   0.0% |
#   Potential matrix:                  0.004     0.004   0.0% |
#  LCAO to grid:                       0.001     0.001   0.0% |
#  Set positions (LCAO WFS):           0.025     0.005   0.0% |
#   Basic WFS set positions:           0.000     0.000   0.0% |
#   Basis functions set positions:     0.000     0.000   0.0% |
#   P tci:                             0.010     0.010   0.0% |
#   ST tci:                            0.006     0.006   0.0% |
#   mktci:                             0.003     0.003   0.0% |
# SCF-cycle:                           1.029     0.023   0.1% |
#  Davidson:                           0.172     0.065   0.3% |
#   Apply hamiltonian:                 0.009     0.009   0.0% |
#   Subspace diag:                     0.026     0.001   0.0% |
#    calc_h_matrix:                    0.017     0.007   0.0% |
#     Apply hamiltonian:               0.009     0.009   0.0% |
#    diagonalize:                      0.005     0.005   0.0% |
#    rotate_psi:                       0.003     0.003   0.0% |
#   calc. matrices:                    0.050     0.032   0.1% |
#    Apply hamiltonian:                0.019     0.019   0.1% |
#   diagonalize:                       0.017     0.017   0.1% |
#   rotate_psi:                        0.004     0.004   0.0% |
#  Density:                            0.072     0.000   0.0% |
#   Atomic density matrices:           0.022     0.022   0.1% |
#   Mix:                               0.037     0.037   0.2% |
#   Multipole moments:                 0.005     0.005   0.0% |
#   Pseudo density:                    0.008     0.002   0.0% |
#    Symmetrize density:               0.006     0.006   0.0% |
#  Hamiltonian:                        0.761     0.001   0.0% |
#   Atomic:                            0.550     0.016   0.1% |
#    XC Correction:                    0.534     0.534   2.5% ||
#   Calculate atomic Hamiltonians:     0.016     0.016   0.1% |
#   Communicate:                       0.000     0.000   0.0% |
#   Hartree integrate/restrict:        0.006     0.006   0.0% |
#   Poisson:                           0.141     0.009   0.0% |
#    Communicate from 1D:              0.019     0.019   0.1% |
#    Communicate from 2D:              0.012     0.012   0.1% |
#    Communicate to 1D:                0.013     0.013   0.1% |
#    Communicate to 2D:                0.016     0.016   0.1% |
#    FFT 1D:                           0.024     0.024   0.1% |
#    FFT 2D:                           0.047     0.047   0.2% |
#   XC 3D grid:                        0.045     0.045   0.2% |
#   vbar:                              0.002     0.002   0.0% |
#  Orthonormalize:                     0.001     0.000   0.0% |
#   calc_s_matrix:                     0.000     0.000   0.0% |
#   inverse-cholesky:                  0.000     0.000   0.0% |
#   projections:                       0.000     0.000   0.0% |
#   rotate_psi_s:                      0.000     0.000   0.0% |
# Set symmetry:                        0.001     0.001   0.0% |
# Other:                              20.095    20.095  94.8% |-------------------------------------|
# -----------------------------------------------------------
# Total:                                        21.207 100.0%
#
# Memory usage: 211.25 MiB
# Date: Tue Mar 14 15:39:02 2023
# Ground state energy: -1.7832 eV
# Fermi energy:        3.9813 eV
