# %%
from src.GPAWCalculator import calc_groundstate, calc_bandstructure
from src.ase_systems import H2_chain
from math import pi

params = {
    'xc'          : 'PBE',                   # Exchange-correlation func. ID
    'h'           : 0.1,                     # Spatial grid size
    'kpoints'     : (8,1,1),                 # k-points sampled in periodic sys
    'random'      : True,                    # Random guess (of what?)
    'convergence' : {'energy' : 0.0005}      # Convergence criteria
    }

sys = H2_chain.System(twist_angle = 0, cell_size = 1)


calc_groundstate(sys, params)
# Out:
# ========== Calculating ground state ==========
# Total energy:     -18.0999 eV
# Potential Energy: -18.0999 eV
# Fermi energy:     -10.8947 eV
# Output file: H2-Nphi-1_GS.log
# Restart file: H2-Nphi-1_GS.gpw

# %%
calc_bandstructure(sys, npoints=100)
# Out:
# Calculating band structure...
